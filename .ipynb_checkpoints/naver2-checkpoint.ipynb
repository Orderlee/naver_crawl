# %%
import re
from fake_useragent import UserAgent
import time
import pandas as pd
import os
import time
import requests
from bs4 import BeautifulSoup
import collections
collections.Callable = collections.abc.Callable

from html_table_parser import parser_functions as parser

# %%
url = 'https://shopping.naver.com/home/p/index.naver'

result = requests.get(url)
bs_obj = BeautifulSoup(result.content, "html.parser")
content = bs_obj.find("ul",{"class":"set_list"})
#print(content)
opens = bs_obj.findAll("li",{"id":"rootCategoryList"})
#print(opens[0])
haha = bs_obj.findAll('button',{'aria-expanded':'false'})
print(haha[0]['category-id'])
#print(opens['category-id'])
# cleared = content.findAll("h2",{"role":"heading"})

# %%
category-id

# %%
url = 'https://search.shopping.naver.com/search/category/100000021'
result = requests.get(url)
bs_obj = BeautifulSoup(result.content, "html.parser")

# %%
print(result.content)
# Out:
# b'<!DOCTYPE html><html lang="ko"><head><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\x87\xbc\xed\x95\x91</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-220623-111430/img/favicon.ico"/><meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\x87\xbc\xed\x95\x91"/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84\xec\x87\xbc\xed\x95\x91 \xec\xb9\xb4\xed\x8
# ...

# %%
items = bs_obj.select('#__next > div > div.style_container__1YjHN > div > div.style_content_wrap__1PzEo > div.style_content__2T20F')
print(items)
# Out:
# [<div class="style_content__2T20F"><div class="seller_filter_area"><h3 class="blind">판매처</h3><ul class="subFilter_seller_filter__3yvWP"><li class=""><a class="subFilter_filter__3Y-uy" href="#" role="button">전체<span class="subFilter_num__2x0jq">119,103,251</span></a></li><li class=""><a class="subFilter_filter__3Y-uy" href="#" role="button">가격비교<span class="subFilter_num__2x0jq">8,980,264</span></a></li><li class=""><a class="subFilter_filter__3Y-uy" href="#" role="button">네이버페이<span class="subFilter_num__2x0jq">56,935,913</span></a></li><li class=""><a class="subFilter_filter__3Y-uy" href="#" role="button">백화점/홈쇼핑<span class="subFilter_num__2x0jq">15,613,224</span></a></li><li class=""><a class="subFilter_filter__3Y-uy" href="#" role="button">쇼핑윈도<span class="subFilter_num__2x0jq">1,634,306</span></a></li><li class=""><a class="subFilter_filter__3Y-uy" href="#" role="button">해외직구<span class="subFilter_num__2x0jq">47,879,912</span></a></li></ul><div class="subFilter_sort_area__ZBnvs">
# ...
