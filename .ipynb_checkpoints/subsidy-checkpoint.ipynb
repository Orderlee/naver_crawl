# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
import pandas as pd
import os
import time
import requests
from bs4 import BeautifulSoup
from html_table_parser import parser_functions as parser
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

# %%
#def subidy_intro():
driver = webdriver.Chrome("./chromedriver")
driver.maximize_window()

# Pageload Strategy 설정 변경 다음 화면으로 넘어갈때 유용
caps = DesiredCapabilities().CHROME
caps["pageLoadStrategy"] = "none"

# 드라이버를 Headless로 만들기 속도 향상 해줌
chrome_options = Options()
chrome_options.headless = True

driver.get("https://ev.or.kr/portal/localInfo")

#current = driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[1]/ul/li[5]/div[1]')
current =driver.find_elements_by_tag_name('//*[@id="lnb"]/ul/li[5]/a')
#/html/body/div[2]/div[3]/div[1]/ul/li[5]/a
#/html/body/div[2]/div[3]/div[1]/ul/li[5]/div[1]
print(type(current))
print(current)
#state = current.find_elements_by_class_name('depth2')

driver.quit()

# %%
driver = webdriver.Chrome("./chromedriver")
driver.maximize_window()

caps = DesiredCapabilities().CHROME
caps["pageLoadStrategy"] = "none"

chrome_options = Options()
chrome_options.headless = True

driver.get("https://ev.or.kr/portal/localInfo")

# url = "https://ev.or.kr/portal/localInfo"
# result = requests.get(url)
# bs_obj = BeautifulSoup(result,'html.parser')
#content = bs_obj.find("div",{"class":"tab_area"})
# content = bs_obj.find('div.tab_area > ul')
# for i in range(1,3):
#     content = content.find('/html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li['+str(i)+']/a')
#     content = content.text
#     print(content)
#content = content.find('li')
#content = content.text
#editForm > div.tab_area > ul
#print(content)


##됨
# url = "https://ev.or.kr/portal/localInfo"
# result = requests.get(url)
# bs_obj = BeautifulSoup(result.content,'html.parser')
# list = bs_obj.select('#editForm > div.tab_area')
# for a in list:
#     a = a.text
#     print(a)

# content = a[i]




car_name =[]

url = "https://ev.or.kr/portal/localInfo"
result = requests.get(url)
bs_obj = BeautifulSoup(result.content,'html.parser')
list = bs_obj.select('#editForm > div.tab_area')
print(list)
#print(type(list))
        #editForm > div.tab_area
#     /html/body/div[2]/div[3]/div[2]/form[2]/div[1]
for a in list:
    a = a.text
    #print(type(a))
    #a = a.strip()
    a = a.split()
    #print(type)
    #print(a[0])
    #a = a.replace('\n',',')
    #car_name.append(a)
    car_name.extend(a)
    car_name = ",".join(car_name)
    
print(car_name[:])
#print(type(car_name))
            

#car_name = "\n".join(car_name)
#content = a[i]
#content[i]
#print(a[i])
#car_name = ",".join(car_name)
# print(type(car_name))
# print(car_name[0])



# for i in range(1,2):
   
#     try: 
#         driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li['+str(i)+']/a').click()
#         driver.implicitly_wait(5)
#         # /html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li[1]/a
#         # /html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li[2]/a
#         # /html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li[3]/a
        
# #         url = "https://ev.or.kr/portal/localInfo"
# #         result = requests.get(url)
# #         bs_obj = BeautifulSoup(result.content,'html.parser')
# #         content = bs_obj.find("div",{"class":"tab_area"})
# #         content = content.find("li")
# #         content = content.text
# #         print(content)
        

#         #click event
#         driver.find_element_by_xpath('//*[@id="btn_car_price"]').click()       
#         driver.implicitly_wait(5)
        
#         driver.switch_to_window(driver.window_handles[1]) 
#         driver.get_window_position(driver.window_handles[1])
    
#     except Exception as e:
#         print("error occur ,", e)
    

#         driver.switch_to_window(driver.window_handles[1]) 
#         driver.get_window_position(driver.window_handles[1])



#     result =[]
#     sido =[]
#     region = []
#     for i in range(1,2):
        
#         try:
#             tbody_2 =driver.find_element_by_xpath('/html/body/form/table')
#             #print(tbody_2)
            
#             sidos = tbody_2.find_elements_by_xpath('body > form > table > tbody > tr:nth-child('+str(1)+') > th:nth-child(2)')
#             #body > form > table > tbody > tr:nth-child(1) > th:nth-child(2)
#             #body > form > table > tbody > tr:nth-child(2) > th:nth-child(2)
#             #print(sidos)
#             #sidos = sidos.strip()
#             #sidos = sidos.text
            
            
#             #sidos = sidos.split(' ')
#             #sidos = sidos.extend(sidos)
#             #sidos= ",".join(sidos)
#             #print(sidos)



#             regions = tbody_2.find_elements_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']/th[2]')
#             #regions = regions.text
#             #regions = regions.strip()
#             #regions = regions.split(' ')
#             regions = regions.extend(regions)
#             #regionss= ",".join(regions)
#             #print(regions)
            
#             driver.find_element_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']/td[1]/a').click()            
#             tbody = driver.find_element_by_xpath('/html/body/form/table/tbody')


#             for i in range(1,100): 
#                 try:
                    
#                     trr = tbody.find_elements_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']')

#                     for trrs in trr:
#                         trrs = trrs.text
#                         trrs = trrs.split(' ')
#                         trrslength = len(trrs)


#                         if trrslength == 6:
#                             car_t = trrs[0]
#                             maker = trrs[1]
#                             model = trrs[2:3]
#                             model = ",".join(model)
#                             model = model.replace(",,",",")
#                             center_g = trrs[3]
#                             local_g = trrs[4]
#                             subsidy = trrs[5]
#                             subsidy =subsidy.replace(",","")

#     #                         print(car_t)
#     #                         print(maker)
#     #                         print(model)
#     #                         print(center_g)
#     #                         print(local_g)
#     #                         print(subsidy)

#                         elif trrslength == 7:
#                             car_t = trrs[0]
#                             maker = trrs[1]
#                             model = trrs[2:4]
#                             model = ",".join(model)
#                             model = model.replace(",,",",")
#                             center_g = trrs[4]
#                             local_g = trrs[5]
#                             subsidy = trrs[6]
#                             subsidy =subsidy.replace(",","")


#     #                         print(car_t)
#     #                         print(maker)
#     #                         print(model)
#     #                         print(center_g)
#     #                         print(local_g)
#     #                         print(subsidy)

#                         elif trrslength == 8:
#                             car_t = trrs[0]
#                             maker = trrs[1]
#                             model = trrs[2:5]
#                             model = ",".join(model)
#                             model = model.replace(",,",",")
#                             center_g = trrs[5]
#                             local_g = trrs[6]
#                             subsidy = trrs[7]
#                             subsidy =subsidy.replace(",","")

#     #                         print(car_t)
#     #                         print(maker)
#     #                         print(model)
#     #                         print(center_g)
#     #                         print(local_g)
#     #                         print(subsidy)

#                         elif trrslength == 9:
#                             car_t = trrs[0]
#                             maker = trrs[1]
#                             model = trrs[2:6]
#                             model = ",".join(model)
#                             model = model.replace(",,",",")
#                             center_g = trrs[6]
#                             local_g = trrs[7]
#                             subsidy = trrs[8]
#                             subsidy =subsidy.replace(",","")


#     #                         print(car_t)
#     #                         print(maker)
#     #                         print(model)
#     #                         print(center_g)
#     #                         print(local_g)
#     #                         print(subsidy)

#                         elif trrslength == 10:
#                             car_t = trrs[0]
#                             maker = trrs[1]
#                             model = trrs[2:7]
#                             model = ",".join(model)
#                             model = model.replace(",,",",")
#                             center_g = trrs[7]
#                             local_g = trrs[8]
#                             subsidy = trrs[9]
#                             subsidy =subsidy.replace(",","")

#     #                         print(car_t)
#     #                         print(maker)
#     #                         print(model)
#     #                         print(center_g)
#     #                         print(local_g)
#     #                         print(subsidy)

#                         elif trrslength == 12:
#                             car_t = trrs[0]
#                             maker = trrs[1]
#                             model = trrs[2:9]
#                             model = ",".join(model)
#                             model = model.replace(",,",",")
#                             center_g = trrs[9]
#                             local_g = trrs[10]
#                             subsidy = trrs[11]
#                             subsidy =subsidy.replace(",","")

#     #                         print(car_t)
#     #                         print(maker)
#     #                         print(model)
#     #                         print(center_g)
#     #                         print(local_g)
#     #                         print(subsidy)



#                     results = [car_t, maker, model, center_g, local_g, subsidy]
#                     result.append(results)
            
#                 except Exception as e:
#                     print("error occur ,", e)

#             driver.find_element_by_xpath('/html/body/form/div/a').click()

#             time.sleep(5)
#         except Exception as e:
#             print("error occur ,", e)
#     #driver.close()
#     driver.switch_to.window(driver.window_handles[0])
    
#     df = pd.DataFrame(result,columns=['type','maker','model','goverment','local','subsidy'])
#     #print(df)
#     df = df.drop_duplicates(['type','maker','model','goverment','local','subsidy'], keep='first')

#     df.to_csv('subsidy.csv',encoding='utf-8-sig', index=False)
#     #df.to_csv('_subsidy.csv',encoding='utf-8-sig', index=False)
    

# print("완료")

# #print(result)
# #print(type(result))

driver.quit()

# %%
driver = webdriver.Chrome("./chromedriver")
driver.maximize_window()

caps = DesiredCapabilities().CHROME
caps["pageLoadStrategy"] = "none"

chrome_options = Options()
chrome_options.headless = True

driver.get("https://ev.or.kr/portal/localInfo")

# url = "https://ev.or.kr/portal/localInfo"
# result = requests.get(url)
# bs_obj = BeautifulSoup(result,'html.parser')
#content = bs_obj.find("div",{"class":"tab_area"})
# content = bs_obj.find('div.tab_area > ul')
# for i in range(1,3):
#     content = content.find('/html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li['+str(i)+']/a')
#     content = content.text
#     print(content)
#content = content.find('li')
#content = content.text
#editForm > div.tab_area > ul
#print(content)


##됨
# url = "https://ev.or.kr/portal/localInfo"
# result = requests.get(url)
# bs_obj = BeautifulSoup(result.content,'html.parser')
# list = bs_obj.select('#editForm > div.tab_area')
# for a in list:
#     a = a.text
#     print(a)

# content = a[i]




car_name =[]

url = "https://ev.or.kr/portal/localInfo"
result = requests.get(url)
bs_obj = BeautifulSoup(result.content,'html.parser')
list = bs_obj.select('#editForm > div.tab_area')
        
for a in list:
    a = a.text
    #print(type(a))
    #a = a.strip()
    a = a.split()
    print(type)
    print(a[0])
    #a = a.replace('\n',',')
    #car_name.append(a)
    car_name.extend(a)
    car_name = ",".join(car_name)
    
#print(car_name[0])
#print(type(car_name))
            

#car_name = "\n".join(car_name)
#content = a[i]
#content[i]
#print(a[i])
#car_name = ",".join(car_name)
# print(type(car_name))
# print(car_name[0])



for i in range(1,2):
   
    try: 
        driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li['+str(i)+']/a').click()
        driver.implicitly_wait(5)
        # /html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li[1]/a
        # /html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li[2]/a
        # /html/body/div[2]/div[3]/div[2]/form[2]/div[1]/ul/li[3]/a
        
#         url = "https://ev.or.kr/portal/localInfo"
#         result = requests.get(url)
#         bs_obj = BeautifulSoup(result.content,'html.parser')
#         content = bs_obj.find("div",{"class":"tab_area"})
#         content = content.find("li")
#         content = content.text
#         print(content)
        

        #click event
        driver.find_element_by_xpath('//*[@id="btn_car_price"]').click()
        driver.implicitly_wait(5)

        driver.switch_to_window(driver.window_handles[1]) 
        driver.get_window_position(driver.window_handles[1])
    
    except Exception as e:
        print("error occur ,", e)
    
        
#         sido =[]
#         regions = []
#         sidos = tbody.find_elements_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']/th[1]')
#         sidos = sidos.text
#         #sidos = sidos.strip()
#         sidos = sidos.split(' ')
#         sidos = sidos.extend(sidos)
#         #sidos= ",".join(sidos)
#         print(sidos)


                    
#         regions = tbody.find_elements_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']/th[2]')
#         regions = regions.text
#         #regions = regions.strip()
#         regions = regions.split(' ')
#         regions = regions.extend(regions)
#         #regionss= ",".join(regions)
#         print(regions)

        driver.switch_to_window(driver.window_handles[1]) 
        driver.get_window_position(driver.window_handles[1])



    result =[]
    for i in range(1,2):
        try:
            driver.find_element_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']/td[1]/a').click()            
            tbody = driver.find_element_by_xpath('/html/body/form/table/tbody')

            for i in range(1,100): 
                try:
                    
                    trr = tbody.find_elements_by_xpath('/html/body/form/table/tbody/tr['+str(i)+']')

                    for trrs in trr:
                        trrs = trrs.text
                        trrs = trrs.split(' ')
                        trrslength = len(trrs)


                        if trrslength == 6:
                            car_t = trrs[0]
                            maker = trrs[1]
                            model = trrs[2:3]
                            model = ",".join(model)
                            model = model.replace(",,",",")
                            center_g = trrs[3]
                            local_g = trrs[4]
                            subsidy = trrs[5]
                            subsidy =subsidy.replace(",","")

    #                         print(car_t)
    #                         print(maker)
    #                         print(model)
    #                         print(center_g)
    #                         print(local_g)
    #                         print(subsidy)

                        elif trrslength == 7:
                            car_t = trrs[0]
                            maker = trrs[1]
                            model = trrs[2:4]
                            model = ",".join(model)
                            model = model.replace(",,",",")
                            center_g = trrs[4]
                            local_g = trrs[5]
                            subsidy = trrs[6]
                            subsidy =subsidy.replace(",","")


    #                         print(car_t)
    #                         print(maker)
    #                         print(model)
    #                         print(center_g)
    #                         print(local_g)
    #                         print(subsidy)

                        elif trrslength == 8:
                            car_t = trrs[0]
                            maker = trrs[1]
                            model = trrs[2:5]
                            model = ",".join(model)
                            model = model.replace(",,",",")
                            center_g = trrs[5]
                            local_g = trrs[6]
                            subsidy = trrs[7]
                            subsidy =subsidy.replace(",","")

    #                         print(car_t)
    #                         print(maker)
    #                         print(model)
    #                         print(center_g)
    #                         print(local_g)
    #                         print(subsidy)

                        elif trrslength == 9:
                            car_t = trrs[0]
                            maker = trrs[1]
                            model = trrs[2:6]
                            model = ",".join(model)
                            model = model.replace(",,",",")
                            center_g = trrs[6]
                            local_g = trrs[7]
                            subsidy = trrs[8]
                            subsidy =subsidy.replace(",","")


    #                         print(car_t)
    #                         print(maker)
    #                         print(model)
    #                         print(center_g)
    #                         print(local_g)
    #                         print(subsidy)

                        elif trrslength == 10:
                            car_t = trrs[0]
                            maker = trrs[1]
                            model = trrs[2:7]
                            model = ",".join(model)
                            model = model.replace(",,",",")
                            center_g = trrs[7]
                            local_g = trrs[8]
                            subsidy = trrs[9]
                            subsidy =subsidy.replace(",","")

    #                         print(car_t)
    #                         print(maker)
    #                         print(model)
    #                         print(center_g)
    #                         print(local_g)
    #                         print(subsidy)

                        elif trrslength == 12:
                            car_t = trrs[0]
                            maker = trrs[1]
                            model = trrs[2:9]
                            model = ",".join(model)
                            model = model.replace(",,",",")
                            center_g = trrs[9]
                            local_g = trrs[10]
                            subsidy = trrs[11]
                            subsidy =subsidy.replace(",","")

    #                         print(car_t)
    #                         print(maker)
    #                         print(model)
    #                         print(center_g)
    #                         print(local_g)
    #                         print(subsidy)



                    results = [car_t, maker, model, center_g, local_g, subsidy]
                    result.append(results)
            
                except Exception as e:
                    print("error occur ,", e)

            driver.find_element_by_xpath('/html/body/form/div/a').click()

            #time.sleep(5)
        except Exception as e:
            print("error occur ,", e)
    #driver.close()
    driver.switch_to.window(driver.window_handles[0])
    
    df = pd.DataFrame(result,columns=['type','maker','model','goverment','local','subsidy'])
    #print(df)
    df = df.drop_duplicates(['type','maker','model','goverment','local','subsidy'], keep='first')

    df.to_csv('subsidy.csv',encoding='utf-8-sig', index=False)
    #df.to_csv('_subsidy.csv',encoding='utf-8-sig', index=False)
    

print("완료")

#print(result)
#print(type(result))

driver.quit()
